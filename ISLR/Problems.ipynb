# %% [markdown]
# These are my solutions going through [Introduction to Statistical Learning](http://faculty.marshall.usc.edu/gareth-james/ISL/).  I am going to be doing all coding problems using Python.

# %% [markdown]
# ## Chapter 2

# %% [markdown]
# <b>1. For each of parts (a) through (d), indicate whether we would generally
# expect the performance of a flexible statistical learning method to be
# better or worse than an inflexible method. Justify your answer.</b>
#
# (a) The sample size n is extremely large, and the number of predictors p is small.
# - A flexible method would perform better due to the large sample size
#
# (b) The number of predictors p is extremely large, and the number
# of observations n is small.
# - An inflexible method would perform better due to the limited number of observations.  A flexible method would lead to overfitting
#
# (c)  The relationship between the predictors and response is highly
# non-linear.
# - A flexible method would perform better due to an inflexible method not being able to handle a highly non-linear relationship
#
# (d) The variance of the error terms, i.e. σ2 = Var(), is extremely
# high.
# - An inflexible method would do better.  A flexible method would likely overfit due to fitting to the error terms

# %% [markdown]
# <b> 2. Explain whether each scenario is a classification or regression problem, and indicate whether we are most interested in inference or prediction. Finally, provide n and p.</b>
#
# (a) We collect a set of data on the top 500 firms in the US. For each
# firm we record profit, number of employees, industry and the
# CEO salary. We are interested in understanding which factors
# affect CEO salary.
# - This would be a regression problem due to CEO salaries being a continuous variable.  We would be most interested in inference for this problem<br>
# n: 500 (500 firms in the US)<br>
# p: profit, number of employees, industry
#
# (b) We are considering launching a new product and wish to know
# whether it will be a success or a failure. We collect data on 20
# similar products that were previously launched. For each product we have recorded whether it was a success or failure, price
# charged for the product, marketing budget, competition price,
# and ten other variables.
# - This would be a classification due to predicting success or failure.  We would be most interested success and failure to see if the new product will be successful or not<br>
# n: 20 (20 similar products)<br>
# p: price charged for the product, marketing budget, competition price, and ten other features
#
# (c) We are interested in predicting the % change in the USD/Euro
# exchange rate in relation to the weekly changes in the world
# stock markets. Hence we collect weekly data for all of 2012. For
# each week we record the % change in the USD/Euro, the %
# change in the US market, the % change in the British market,
# and the % change in the German market.
# - This would be a regression due to predicting % change which is a continuous variable.  We would be most interested in prediction<br>
# n: 52 (weekly data for all of 2012)<br>
# p: % change in the US market, % change in the British market, % change in the German market

# %% [markdown]
# <b> 3. We now revisit the bias-variance decomposition </b>
#
# (a) Provide a sketch of typical (squared) bias, variance, training error, test error, and Bayes (or irreducible) error curves, on a single plot, as we go from less flexible statistical learning methods
# towards more flexible approaches. The x-axis should represent
# the amount of flexibility in the method, and the y-axis should
# represent the values for each curve. There should be five curves.
# Make sure to label each one.
# ![](img/3a.jpg)
#
# (b)  Explain why each of the five curves has the shape displayed in
# part (a).
# - Bias - as the flexibility of the model increases the bias decreases
# - Variance - as the flexibility of the model increases the variance increases
# - Training Error - as the flexibility of the model increases the training error decreases
# - Test Error - as the flexibility of the model increases the test error decreases, then as it starts to overfit it increases
# - Bayes (irreducible) error - does not change as the flexibility increases (this is also the best the test error can be)

# %% [markdown]
# <b> 4. You will now think of some real-life applications for statistical learning.</b>
#
# (a) Describe three real-life applications in which classification might
# be useful. Describe the response, as well as the predictors. Is the
# goal of each application inference or prediction? Explain your
# answer
# - Predicting whether an airplane will be late arriving to the next airport.  The response would be binary (late or not).  Predictors we could use arrival airport, departure airport, airline, amount of time ahead or behind the plane was previously.  This would primary be a prediction problem
# - Looking at which factors influence whether a football player gets injured.  The response would be whether the player was hurt on the play (binary). Predictors would be the players position, speed they were traveling on the play, speed at which they were tackled, direction they were traveling, height, weight.  This would primary be an inference problem
# - Predicting whether someone gets hired for a job.  The response would be binary (hired or not).  Predictors would be information found on their resume - experience, education, etc.  This would primary be a prediction problem
#
# (b)  Describe three real-life applications in which regression might
# be useful. Describe the response, as well as the predictors. Is the
# goal of each application inference or prediction? Explain your
# answer.
# - Predict the price of a stock the next day.  Response would be the price of the stock.  Predictors would be previous prices of the stock, previous S&P 500 prices, sentiment of major finance newspapers headlines.  This would primary be a prediction problem.
# - Looking at the factors that go into the weight of a cat.  Response would be the weight of a cat.  Predictors would be the diet of the cat and amount of time spent playing.  This would primary be an inference problem.
# - Predicting the weather the next day.  Response would be the temperature for the next day.  Predictors would be current weather and current weather in other nearby cities.  This would primary be a prediction problem.
#
# (c) Describe three real-life applications in which cluster analysis
# might be useful.
# - Clustering different customers for a ski resort.  You could cluster based on the number of times they have visited the resort, amount spent, type of ticket.  This could then be used to make custom marketing campaigns to each of the clusters.
# - Cluster different countries.  This could be done using different economic factors.  This would allow you to see which countries are similar economically.
# - Cluster twitter users.  This could be done using how often they tweet and common topics they tweet about.

# %% [markdown]
# <b>5. What are the advantages and disadvantages of a very flexible (versus
# a less flexible) approach for regression or classification? Under what
# circumstances might a more flexible approach be preferred to a less
# flexible approach? When might a less flexible approach be preferred? </b>
# - A flexible approach typically do better with data where the true relationship is non-linear.  The downside of flexible methods is they can overfit.  It is best to use a less flexible approach if the true relationship of the data is linear.  Flexible approaches are also more difficult to interpret, so if inference is a priority you should go a less flexible approach.

# %% [markdown]
# <b>6. Describe the differences between a parametric and a non-parametric
# statistical learning approach. What are the advantages of a parametric approach to regression or classification (as opposed to a nonparametric approach)? What are its disadvantages?</b>
# - Parametric models make an assumption about the true relationship of the data, while non-parametric model doe not make an assumption.  The advantage of parametric models is they are typically easy to interpret, but are not as accurate as non-parametric models.

# %% [markdown]
# <b> 7. The table below provides a training data set containing six observations, three predictors, and one qualitative response variable.
# ![](img/7.png)
# Suppose we wish to use this data set to make a prediction for Y when
# X1 = X2 = X3 = 0 using K-nearest neighbors.</b>
#
# (a) Compute the Euclidean distance between each observation and
# the test point, X1 = X2 = X3 = 0.
# - I am going to use python to solve this

# %%
import numpy as np

# make all features into a list
x1_list = [0, 2, 0, 0, -1, 1]
x2_list = [3, 0, 1, 1, 0, 1]
x3_list = [0, 0, 3, 2, 1, 1]
y_list = ['Red', 'Red', 'Red', 'Green', 'Green', 'Red']

for x1, x2, x3 in zip(x1_list, x2_list, x3_list):
    print(np.round(np.sqrt((x1-0)**2 + (x2-0)**2 + (x3-0)**2), 2))
# Out:
# 3.0
# 2.0
# 3.16
# 2.24
# 1.41
# 1.73

# %% [markdown]
# (b) What is our prediction with K = 1? Why?
#
# - The point that is closes is observation number 5 (due to have the smallest Euclidean distance of 1.41).  Since point number 5 is green, I would predict the test point is green.<br>

# %% [markdown]
# (c) What is our prediction with K = 3? Why?
# - The 3 nearest points are observation number 5, number 6, and number 2.  I would predict the test point to be red because number 6 and 2 are red<br>

# %% [markdown]
# (d) If the Bayes decision boundary in this problem is highly nonlinear, then would we expect the best value for K to be large or
# small? Why?
# - I would expect the best value for K to be small.  This is because when the value is small in KNN - this makes the model more flexible

# %% [markdown]
# <b>8. This exercise relates to the College data set, which can be found in
# the file College.csv. It contains a number of variables for 777 different
# universities and colleges in the US. The variables are
# - Private : Public/private indicator
# - Apps : Number of applications received
# - Accept : Number of applicants accepted
# - Enroll : Number of new students enrolled
# - Top10perc : New students from top 10 % of high school class
# - Top25perc : New students from top 25 % of high school class
# - F.Undergrad : Number of full-time undergraduates
# - P.Undergrad : Number of part-time undergraduates
# - Outstate : Out-of-state tuition
# - Room.Board : Room and board costs
# - Books : Estimated book costs
# - Personal : Estimated personal spending
# - PhD : Percent of faculty with Ph.D.’s
# - Terminal : Percent of faculty with terminal degree
# - S.F.Ratio : Student/faculty ratio
# - perc.alumni : Percent of alumni who donate
# - Expend : Instructional expenditure per student
# - Grad.Rate : Graduation rate
# Before reading the data into R, it can be viewed in Excel or a text
# editor.<b>

# %% [markdown]
# (a) Use the read.csv() function to read the data into R. Call the
# loaded data college. Make sure that you have the directory set
# to the correct location for the data.

# %%
import pandas as pd

df = pd.read_csv('data/College.csv')
df.head()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %% [markdown]
# (b) ) Look at the data using the fix() function. You should notice
# that the first column is just the name of each university. We don’t
# really want R to treat this as data. However, it may be handy to
# have these names for later.

# %%
df.set_index('Unnamed: 0', inplace = True)
df.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# Unnamed: 0
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# Unnamed: 0
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
# ...

# %% [markdown]
# (c) i. Use the summary() function to produce a numerical summary
# of the variables in the data set.

# %%
df.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# ii. Use the pairs() function to produce a scatterplot matrix of
# the first ten columns or variables of the data. Recall that
# you can reference the first ten columns of a matrix A using
# A[,1:10].

# %%
import seaborn as sns
import matplotlib.pyplot as plt 

sns.pairplot(df.iloc[:, :10])
plt.show()
# Out:
# /Users/jeffreyherman/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df['Private']
# Out:
# Unnamed: 0
# Abilene Christian University      Yes
# Adelphi University                Yes
# Adrian College                    Yes
# Agnes Scott College               Yes
# Alaska Pacific University         Yes
#                                  ...
# Worcester State College            No
# Xavier University                 Yes
# Xavier University of Louisiana    Yes
# Yale University                   Yes
# York College of Pennsylvania      Yes
# Name: Private, Length: 777, dtype: object

# %%
fig = plt.subplots(figsize = (8, 6))

ax1 = plt.subplot(121)
df['Outstate'].plot(kind = 'box', ax = ax1)
ax1.set_xticks([],)
ax1.set_title('Outstate - All')

ax2 = plt.subplot(122)
df[df['Private'] == 'Yes']['Outstate'].plot(kind = 'box', ax = ax2)
ax2.set_xticks([],)
ax2.set_title('Outstate - Private')
# Out:
# Text(0.5, 1.0, 'Outstate - Private')

# %% [markdown]
# iv. Create a new qualitative variable, called Elite, by binning
# the Top10perc variable. We are going to divide universities
# into two groups based on whether or not the proportion
# of students coming from the top 10 % of their high school
# classes exceeds 50 %.

# %%
df['Elite'] = df['Top10perc'].map(lambda x: 1 if x > 50 else 0)

# %% [markdown]
# Use the summary() function to see how many elite universities there are. Now use the plot() function to produce
# side-by-side boxplots of Outstate versus Elite

# %%
df['Elite'].value_counts()
# Out:
# 0    699
# 1     78
# Name: Elite, dtype: int64

# %%
fig = plt.subplots(figsize = (8, 6))

ax1 = plt.subplot(121)
df['Outstate'].plot(kind = 'box', ax = ax1)
ax1.set_xticks([],)
ax1.set_title('Outstate - All')

ax2 = plt.subplot(122)
df[df['Elite'] == 1]['Outstate'].plot(kind = 'box', ax = ax2)
ax2.set_xticks([],)
ax2.set_title('Outstate - Elite')
# Out:
# Text(0.5, 1.0, 'Outstate - Elite')

# %% [markdown]
# v. Use the hist() function to produce some histograms with
# differing numbers of bins for a few of the quantitative variables.

# %%
plt.hist(df['Outstate'], bins = 30);

# %%
plt.hist(df['Outstate'], bins = 300);

# %%
plt.hist(df['Enroll']);

# %% [markdown]
# vi. Continue exploring the data, and provide a brief summary
# of what you discover

# %% [markdown]
# A lot of the data is skewed to the right and there were some features that had a linear relationship, for example see below:

# %%
plt.scatter(df['Enroll'], df['F.Undergrad'])

# %% [markdown]
# <b>9. This exercise involves the Auto data set studied in the lab. Make sure
# that the missing values have been removed from the data.</b>

# %%
df = pd.read_csv('data/Auto.csv')
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0        130    3504          12.0    70
# 1  15.0          8         350.0        165    3693          11.5    70
# 2  18.0          8         318.0        150    3436          11.0    70
# 3  16.0          8         304.0        150    3433          12.0    70
# 4  17.0          8         302.0        140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
# check missing values 
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# year            0
# origin          0
# name            0
# dtype: int64

# %%
# check datatypes 
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# year              int64
# origin            int64
# name             object
# dtype: object

# %%
df = df[df['horsepower'] != '?'].copy()
df['horsepower'] = df['horsepower'].astype(int)

# %% [markdown]
# (a) Which of the predictors are quantitative, and which are qualitative?

# %%
for x in df.columns[:-1]:
    plt.hist(df[x])
    plt.title(x)
    plt.show()

# %% [markdown]
# - Quantitative: mpg, displacement, horsepower, weight, acceleration, year
# - Qualitative: cylinders, origin,

# %% [markdown]
# (b) What is the range of each quantitative predictor?

# %%
for x in df.columns[:-1]:
    if x not in ['cylinders', 'origin']:
        min_val = df[x].min()
        max_val = df[x].max()
        range_val = max_val - min_val
        print(f'{x} - min {min_val} - max {max_val} - range {range_val}')
# Out:
# mpg - min 9.0 - max 46.6 - range 37.6
# displacement - min 68.0 - max 455.0 - range 387.0
# horsepower - min 46 - max 230 - range 184
# weight - min 1613 - max 5140 - range 3527
# acceleration - min 8.0 - max 24.8 - range 16.8
# year - min 70 - max 82 - range 12

# %% [markdown]
# (c) What is the mean and standard deviation of each quantitative
# predictor?

# %%
for x in df.columns[:-1]:
    if x not in ['cylinders', 'origin']:
        mean_val = df[x].mean()
        std_val = df[x].std()
        print(f'{x} - mean {mean_val} - std {std_val}')
# Out:
# mpg - mean 23.44591836734694 - std 7.805007486571799
# displacement - mean 194.41198979591837 - std 104.64400390890465
# horsepower - mean 104.46938775510205 - std 38.49115993282855
# weight - mean 2977.5841836734694 - std 849.4025600429494
# acceleration - mean 15.541326530612228 - std 2.7588641191880816
# year - mean 75.9795918367347 - std 3.6837365435778318

# %% [markdown]
# (d) Now remove the 10th through 85th observations. What is the
# range, mean, and standard deviation of each predictor in the
# subset of the data that remains?

# %%
# reset index due to dropping rows earlier 
df.reset_index(inplace = True, drop = True)
df_drop = df.drop(range(9, 86))

# %%
for x in df_drop.columns[:-1]:
    if x not in ['cylinders', 'origin']:
        range_val = df_drop[x].max() - df_drop[x].min()
        mean_val = df_drop[x].mean()
        std_val = df_drop[x].std()
        print(f'{x}: range {range_val} - mean {mean_val} - std {std_val}')
# Out:
# mpg: range 35.6 - mean 24.437460317460314 - std 7.8578246062259565
# displacement: range 387.0 - mean 186.86984126984126 - std 99.61859851632575
# horsepower: range 184 - mean 100.56507936507937 - std 35.657045465312144
# weight: range 3348 - mean 2933.6349206349205 - std 811.5253998322197
# acceleration: range 16.3 - mean 15.74031746031746 - std 2.687407511816318
# year: range 12 - mean 77.15873015873017 - std 3.102322682391362

# %% [markdown]
# (e) Using the full data set, investigate the predictors graphically,
# using scatterplots or other tools of your choice. Create some plots
# highlighting the relationships among the predictors. Comment
# on your findings

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# There appears to be linear relationship between some of the features (acceleration vs horsepower, horsepower vs weight)

# %% [markdown]
# (f) Suppose that we wish to predict gas mileage (mpg) on the basis
# of the other variables. Do your plots suggest that any of the
# other variables might be useful in predicting mpg? Justify your
# answer.
# - Looks like displacement, horsepower, weight, acceleration, year, and origin all have a relationship with mpg and could be useful in predicting mpg.

# %% [markdown]
# <b>10. This exercise involves the Boston housing data set.</b>
#
# (a)  This exercise involves the Boston housing data set.

# %%
from sklearn.datasets import load_boston

boston = load_boston()


bos = pd.DataFrame(boston.data)
bos.columns = boston.feature_names
bos['PRICE'] = boston.target

# %% [markdown]
# How many rows are in this data set? How many columns? What
# do the rows and columns represent?

# %%
bos.shape
# Out:
# (506, 14)

# %% [markdown]
# 506 rows and 14 columns

# %%
bos.loc[0]
# Out:
# CRIM         0.00632
# ZN          18.00000
# INDUS        2.31000
# CHAS         0.00000
# NOX          0.53800
# RM           6.57500
# AGE         65.20000
# DIS          4.09000
# RAD          1.00000
# TAX        296.00000
# PTRATIO     15.30000
# B          396.90000
# LSTAT        4.98000
# PRICE       24.00000
# Name: 0, dtype: float64

# %% [markdown]
# This dataset represents different characteristics about houses in the city of Boston.

# %% [markdown]
# (b) Make some pairwise scatterplots of the predictors (columns) in
# this data set. Describe your findings.

# %%
sns.pairplot(bos)
plt.show()

# %% [markdown]
# Does not appear that the majority of features have a linear relationship

# %% [markdown]
# (c)  Are any of the predictors associated with per capita crime rate?
# If so, explain the relationship.

# %%
for x in bos.columns:
    if x != 'CRIM':
        plt.scatter(bos[x], bos['CRIM'])
        plt.xlabel(x)
        plt.ylabel('CRIM')
        plt.show()

# %% [markdown]
# Crime appears to have a relationship with the following features DIS and AGE.  As AGE increases CRIM increases.  As DIS increases CRIM decreases

# %% [markdown]
# (d) Do any of the suburbs of Boston appear to have particularly
# high crime rates? Tax rates? Pupil-teacher ratios? Comment on
# the range of each predictor.

# %% [markdown]
# The DIS feature is the distance to five Boston employment centres.  I'm going to consider suburbs any row where the distance is greater than 8 miles.

# %%
suburbs = bos[bos['DIS'] > 8].copy()
plt.hist(suburbs['CRIM'])
plt.title('CRIM');

# %%
plt.hist(suburbs['TAX'])
plt.title('TAX');

# %%
plt.hist(suburbs['PTRATIO'])
plt.title('PTRATIO');

# %% [markdown]
# There does appear to be a couple of suburbs that have higher CRIM, TAX, and PTRATIO than the other suburbs

# %% [markdown]
# (e) How many of the suburbs in this data set bound the Charles
# river?

# %%
suburbs['CHAS'].value_counts()
# Out:
# 0.0    22
# Name: CHAS, dtype: int64

# %% [markdown]
# No suburbs bound the Charles River

# %% [markdown]
# (f) What is the median pupil-teacher ratio among the towns in this
# data set?

# %%
bos['PTRATIO'].median()
# Out:
# 19.05

# %% [markdown]
# (g) Which suburb of Boston has lowest median value of owner occupied homes? What are the values of the other predictors
# for that suburb, and how do those values compare to the overall
# ranges for those predictors? Comment on your findings.

# %%
bos[bos['PRICE'] == bos['PRICE'].min()]
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 398  38.3518  0.0   18.1   0.0  0.693  5.453  100.0  1.4896  24.0  666.0
# 405  67.9208  0.0   18.1   0.0  0.693  5.683  100.0  1.4254  24.0  666.0
#
#      PTRATIO       B  LSTAT  PRICE
# 398     20.2  396.90  30.59    5.0
# 405     20.2  384.97  22.98    5.0

# %%
bos.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# There are 2 cities that have the lowest price.  They have significantly higher CRIM, in the 75th percentile for INDUS, and are very old.

# %% [markdown]
# (h)  In this data set, how many of the suburbs average more than
# seven rooms per dwelling? More than eight rooms per dwelling?
# Comment on the suburbs that average more than eight rooms
# per dwelling.

# %%
len(bos[bos['RM'] > 7])
# Out:
# 64

# %% [markdown]
# 64 suburbs more than 7 rooms per dwelling

# %%
len(bos[bos['RM'] > 8])
# Out:
# 13

# %% [markdown]
# 13 suburbs more than 8 rooms per dwelling

# %% [markdown]
# ## Chapter 3
#
# ### Notes

# %% [markdown]
# The least squares approach chooses the `beta_0` and `beta_1` to minimize the RSS.  They have the following formulas:
#
# ```
# def beta_1(target, predictor):
#     numerator = []
#     denominator = []
#     for x, y in zip(predictor, target):
#         num_val = (x - np.mean(predictor)) * (y - np.mean(target))
#         denom_val = (x - np.mean(predictor))**2
#         numerator.append(num_val)
#         denominator.append(denom_val)
#     return np.sum(numerator) / np.sum(denominator)
#
# def beta_0(target, predictor, beta_1):
#     return np.mean(target) - beta_1 * np.mean(predictor)
# ```

# %% [markdown]
# Lets see this in action with the advertising dataset

# %%
df = pd.read_csv('data/Advertising.csv', index_col = 0)
df.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %% [markdown]
# I am going to use TV to predict Sales

# %%
def beta_1(target, predictor):
    numerator = []
    denominator = []
    for x, y in zip(predictor, target):
        num_val = (x - np.mean(predictor)) * (y - np.mean(target))
        denom_val = (x - np.mean(predictor))**2
        numerator.append(num_val)
        denominator.append(denom_val)
    return np.sum(numerator) / np.sum(denominator)

# %%
def beta_0(target, predictor, beta_1):
    return np.mean(target) - beta_1 * np.mean(predictor)

# %%
target = df['sales']
predictor = df['TV']

# %%
beta_1_coef = beta_1(target, predictor)
beta_0_coef = beta_0(target, predictor, beta_1_coef)
beta_1_coef, beta_0_coef
# Out:
# (0.047536640433019736, 7.032593549127698)

# %% [markdown]
# As a sanity check I am going to compare it vs statsmodels

# %%
import statsmodels.api as sm

predictor = sm.add_constant(predictor)
model = sm.OLS(target, predictor).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.612
# Model:                            OLS   Adj. R-squared:                  0.610
# Method:                 Least Squares   F-statistic:                     312.1
# Date:                Sat, 01 Aug 2020   Prob (F-statistic):           1.47e-42
# Time:                        10:50:10   Log-Likelihood:                -519.05
# No. Observations:                 200   AIC:                             1042.
# Df Residuals:                     198   BIC:                             1049.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          7.0326      0.458     15.360      0.000       6.130       7.935
# ...

# %% [markdown]
# I see that I get the same coefficients for the constant and the TV coefficient.

# %% [markdown]
# Now I want to see how the best fit line changes as I take different subsets of the data.  I am going to create data where the x value ranges from 1 to 100.  The y value is going to be `2 + 3*x + random variable`

# %%
np.random.seed(11)

# %%
y = [2 + 3*x + np.random.normal(scale = 70) for x in range(1, 101)]
x = range(1, 101)

# %%
plt.scatter(x, y)
plt.plot(x, [2 + 3 * i for i in x], color = 'k', lw = 4)

# %% [markdown]
# The blue points are the actual points and the black line is the true relationship `2 + 3x`.  Now lets see what the least squares line is.

# %%
beta_1_coef_ls = beta_1(y, x)
beta_0_coef_ls = beta_0(y, x, beta_1_coef)
beta_1_coef_ls, beta_0_coef_ls
# Out:
# (3.118082771059057, 151.9056742199164)

# %%
plt.scatter(x, y)
plt.plot(x, [2 + 3 * i for i in x], color = 'k', lw = 2, label = 'True')
plt.plot(x, [beta_0_coef_ls + beta_1_coef_ls * i for i in x], color = 'red', lw = 2, label = 'Least Squares')
plt.legend()

# %% [markdown]
# We see that the least squares line is very close to the actual line.  Lets see what happens when we fit on only parts of the data.

# %%
plt.plot(x, [2 + 3 * i for i in x], color = 'k', lw = 2, label = 'True')
plt.plot(x, [beta_0_coef_ls + beta_1_coef_ls * i for i in x], color = 'red', lw = 2, label = 'Least Squares')
for i in range(10):
    random_subset = np.random.choice(range(0, 99), size = 10)
    x_random_subuset = [x[i] for i in random_subset]
    y_random_subuset = [y[i] for i in random_subset]
    beta_1_coef = beta_1(y_random_subuset, x_random_subuset)
    beta_0_coef = beta_0(y_random_subuset, x_random_subuset, beta_1_coef)
    plt.scatter(x, y)
    plt.plot(x, [beta_0_coef + beta_1_coef * i for i in x], color = 'blue', lw = 1, alpha = .7)
    plt.legend()

# %% [markdown]
# The blue lines are 10 random subsets of the data of size 10.  We see that there is a slight difference between each of the random samples.

# %% [markdown]
# Single Variable Regression vs Multiple Regression

# %%
predictor = sm.add_constant(predictor)
model = sm.OLS(target, predictor).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.612
# Model:                            OLS   Adj. R-squared:                  0.610
# Method:                 Least Squares   F-statistic:                     312.1
# Date:                Sat, 01 Aug 2020   Prob (F-statistic):           1.47e-42
# Time:                        10:50:10   Log-Likelihood:                -519.05
# No. Observations:                 200   AIC:                             1042.
# Df Residuals:                     198   BIC:                             1049.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          7.0326      0.458     15.360      0.000       6.130       7.935
# ...

# %%
predictor = df['radio']
predictor = sm.add_constant(predictor)
model = sm.OLS(target, predictor).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.332
# Model:                            OLS   Adj. R-squared:                  0.329
# Method:                 Least Squares   F-statistic:                     98.42
# Date:                Sat, 01 Aug 2020   Prob (F-statistic):           4.35e-19
# Time:                        10:50:10   Log-Likelihood:                -573.34
# No. Observations:                 200   AIC:                             1151.
# Df Residuals:                     198   BIC:                             1157.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          9.3116      0.563     16.542      0.000       8.202      10.422
# ...

# %%
predictor = df['newspaper']
predictor = sm.add_constant(predictor)
model = sm.OLS(target, predictor).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.052
# Model:                            OLS   Adj. R-squared:                  0.047
# Method:                 Least Squares   F-statistic:                     10.89
# Date:                Sat, 01 Aug 2020   Prob (F-statistic):            0.00115
# Time:                        10:50:10   Log-Likelihood:                -608.34
# No. Observations:                 200   AIC:                             1221.
# Df Residuals:                     198   BIC:                             1227.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         12.3514      0.621     19.876      0.000      11.126      13.577
# ...

# %% [markdown]
# We see all of the coefficients - TV, radio, and newspaper are statically significant.  Now lets try it with multiple regression.

# %%
predictor = df[['radio', 'newspaper', 'TV']]
predictor = sm.add_constant(predictor)
model = sm.OLS(target, predictor).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     570.3
# Date:                Sat, 01 Aug 2020   Prob (F-statistic):           1.58e-96
# Time:                        10:50:10   Log-Likelihood:                -386.18
# No. Observations:                 200   AIC:                             780.4
# Df Residuals:                     196   BIC:                             793.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.9389      0.312      9.422      0.000       2.324       3.554
# ...

# %% [markdown]
# Now we see that newspaper is not statistically significant.

# %%
df.corr()
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.056648  0.782224
# radio      0.054809  1.000000   0.354104  0.576223
# newspaper  0.056648  0.354104   1.000000  0.228299
# sales      0.782224  0.576223   0.228299  1.000000

# %% [markdown]
# This is most likely caused due to radio and newspaper being correlated to each other.  What is happening is in markets where we spend more on radio advertising, more is also being spent on newspaper.  Also in markets where we spend more on radio, sales also increases.

# %% [markdown]
# ## Chapter 3 Exercises

# %% [markdown]
# <b>1.  Describe the null hypotheses to which the p-values given in Table 3.4
# correspond. Explain what conclusions you can draw based on these
# p-values. Your explanation should be phrased in terms of sales, TV,
# radio, and newspaper, rather than in terms of the coefficients of the
# linear model. </b>
#
# - The null hypothesis is that each of the coefficients are zero.  The p-value for TV and radio are both close to zero, so we would reject the null hypothesis and conclude that there coefficients are not zero (thus important for predicting advertising).  The p-value for newspaper is 0.86, which means we believe it is 0.  This means that newspaper is not useful for predicting advertising.

# %% [markdown]
# <b>2. Carefully explain the differences between the KNN classifier and KNN
# regression methods. </b>
# - KNN classifier uses the K-Nearest Neighbors to predict what class a particular point belongs to.  For example if we select K to be 3 and we have an unknown point, we look at the 3 points that are closest in the feature space and have them decide which class the unknown point belongs to.  KNN regression uses the K-Nearest Neighbors to predict the value of an unknown point.  For example if we select K to be 3 for an unknown point, we look at the 3 points that are closest in the feature space and take the mean of the unknown value for those 3 points to be predicting value for the unknown point.

# %% [markdown]
# <b>3. Suppose we have a data set with five predictors, X1 = GPA, X2 = IQ,
# X3 = Gender (1 for Female and 0 for Male), X4 = Interaction between
# GPA and IQ, and X5 = Interaction between GPA and Gender. The
# response is starting salary after graduation (in thousands of dollars).
# Suppose we use least squares to fit the model, and get βˆ0 = 50, βˆ1 =
# 20, βˆ2 = 0.07, βˆ3 = 35, βˆ4 = 0.01, βˆ5 = −10.<br>
# <br>
# (a) Which answer is correct, and why?<br>
# <br>
# i. For a fixed value of IQ and GPA, males earn more on average
# than females.<br>
# ii. For a fixed value of IQ and GPA, females earn more on
# average than males.<br>
# iii. For a fixed value of IQ and GPA, males earn more on average
# than females provided that the GPA is high enough.<br>
# iv. For a fixed value of IQ and GPA, females earn more on
# average than males provided that the GPA is high enough.</b>
# <br>
# - Writing out the formula 50 + GPA(20) + IQ(0.07) + Gender_Female(35) + Gender_Female_IQ(0.01) + Gender_Female_GPA(-10)
# - Based on this formula, `iii` is correct.  This is because the interaction term that includes gender and GPA is -10, which when gender is equal to male would be -10 x 0 = 0

# %% [markdown]
# <b>(b) Predict the salary of a female with IQ of 110 and a GPA of 4.0.</b>

# %%
gpa = 4
iq = 110
50 + (gpa * 20) + (iq * 0.07) + (1 * 35) + (1 * iq * 0.01) + (1 * 4 * -10)
# Out:
# 133.79999999999998

# %% [markdown]
# <b>(c) True or false: Since the coefficient for the GPA/IQ interaction
# term is very small, there is very little evidence of an interaction
# effect. Justify your answer</b>
# - False.  We would need to examine the p-value of this coefficient

# %% [markdown]
# <b>4. I collect a set of data (n = 100 observations) containing a single
# predictor and a quantitative response. I then fit a linear regression
# model to the data, as well as a separate cubic regression, i.e. Y =
# β0 + β1X + β2X2 + β3X3 + error<br>
# <br>(a) Suppose that the true relationship between X and Y is linear,
# i.e. Y = β0 + β1X + . Consider the training residual sum of
# squares (RSS) for the linear regression, and also the training
# RSS for the cubic regression. Would we expect one to be lower
# than the other, would we expect them to be the same, or is there
#     not enough information to tell? Justify your answer.</b></br>
# - Even though the data is linear, I would expect the RSS to be lower for the cubic regression.  This is because the additional parameters would lead to the model slightly overfitting.<br>

# %% [markdown]
# <b>(b) Answer (a) using test rather than training RSS.</b>
# - I would expect the linear model to have a lower RSS as the true relationship is linear.

# %% [markdown]
# <b>(c) Suppose that the true relationship between X and Y is not linear,
# but we don’t know how far it is from linear. Consider the training
# RSS for the linear regression, and also the training RSS for the
# cubic regression. Would we expect one to be lower than the
# other, would we expect them to be the same, or is there not
# enough information to tell? Justify your answer.</b>
# - I would expect the cubic regression to have a lower RSS due to this model being more flexible

# %% [markdown]
# <b>(d) Answer (c) using test rather than training RSS.</b>
# - Without knowing the underlying shape of the data, there is not enough information to tell

# %% [markdown]
# <b> Consider the fitted values that result from performing linear regression without an intercept. In this setting, the ith fitted value takes the form </b>
# ![](img/lr_5.png)
# What is ai?

# %% [markdown]
# <b>8. 8. This question involves the use of simple linear regression on the Auto
# data set.
# (a) Use the lm() function to perform a simple linear regression with
# mpg as the response and horsepower as the predictor. Use the
# summary() function to print the results. Comment on the output. </b>

# %%
# load in auto dataset 
df = pd.read_csv('data/Auto.csv')
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0        130    3504          12.0    70
# 1  15.0          8         350.0        165    3693          11.5    70
# 2  18.0          8         318.0        150    3436          11.0    70
# 3  16.0          8         304.0        150    3433          12.0    70
# 4  17.0          8         302.0        140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
# horsepower is an object
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# year              int64
# origin            int64
# name             object
# dtype: object

# %%
df = df[df['horsepower'] != '?']
df['horsepower'] = df['horsepower'].astype(int)
# Out:
# /Users/jeffreyherman/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
from statsmodels.formula.api import ols
formula = 'mpg ~ horsepower'
model = ols(formula=formula, data=df).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.606
# Model:                            OLS   Adj. R-squared:                  0.605
# Method:                 Least Squares   F-statistic:                     599.7
# Date:                Sat, 01 Aug 2020   Prob (F-statistic):           7.03e-81
# Time:                        11:05:27   Log-Likelihood:                -1178.7
# No. Observations:                 392   AIC:                             2361.
# Df Residuals:                     390   BIC:                             2369.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     39.9359      0.717     55.660      0.000      38.525      41.347
# ...

# %% [markdown]
# <b>i. Is there a relationship between the predictor and the response?</b>
#
# There is a relationship between the predictor and the response.  I can tell this by the high R^2 and the F-statistic being large.

# %% [markdown]
# <b> ii. How strong is the relationship between the predictor and
# the response?</b>
#
# Horsepower accounts for 61% of the variation in mpg

# %% [markdown]
# <b> iii. Is the relationship between the predictor and the response
# positive or negative? </b>
#
# The relationship is negative.  I can see this due to the coefficient for horsepower being -0.1578.  This means as the horsepower increases, the mpg decreases

# %% [markdown]
# <b> iv. What is the predicted mpg associated with a horsepower of
# 98? What are the associated 95 % confidence and prediction
# intervals? </b>

# %%
model.predict({'horsepower': 98})
# Out:
# 0    24.467077
# dtype: float64

# %%
model.conf_int()
# Out:
#                     0          1
# Intercept   38.525212  41.346510
# horsepower  -0.170517  -0.145172

# %% [markdown]
# <b>(b) Plot the response and the predictor. Use the abline() function
# to display the least squares regression line. </b>

# %%
plt.scatter(df['horsepower'], df['mpg'])
plt.plot([df['horsepower'].min(), df['horsepower'].max()], 
        model.predict({'horsepower': [df['horsepower'].min(), df['horsepower'].max()]}),
        lw = 5, color = 'k')
plt.xlabel('horsepower')
plt.ylabel('mpg')
# Out:
# Text(0, 0.5, 'mpg')

# %%
model.predict({'horsepower': [df['horsepower'].min(), df['horsepower'].max()]})
# Out:
# 0    32.675003
# 1     3.631572
# dtype: float64

# %% [markdown]
# <b> (c) Use the plot() function to produce diagnostic plots of the least
# squares regression fit. Comment on any problems you see with
# the fit. </b>

# %%
ls
# Out:
# Default.csv     Problems.ipynb  data/           img/

# %%
df = pd.read_csv('Default.csv')

# %%
df.head()
# Out:
#   default student      balance        income
# 0      No      No   729.526495  44361.625074
# 1      No     Yes   817.180407  12106.134700
# 2      No      No  1073.549164  31767.138947
# 3      No      No   529.250605  35704.493935
# 4      No      No   785.655883  38463.495879

# %%
df['default'] = df['default'].apply(lambda x: 1 if x == 'Yes' else 0)
df['student'] = df['student'].apply(lambda x: 1 if x == 'Yes' else 0)

# %%
df.head()
# Out:
#    default  student      balance        income
# 0        0        0   729.526495  44361.625074
# 1        0        1   817.180407  12106.134700
# 2        0        0  1073.549164  31767.138947
# 3        0        0   529.250605  35704.493935
# 4        0        0   785.655883  38463.495879

# %%
df.dtypes
# Out:
# default      int64
# student      int64
# balance    float64
# income     float64
# dtype: object

# %%
df.to_csv('Default.csv', index = False)
